# %%
file= open("C:\\Users\\BAPS\\Desktop\\Untitled Folder\\disney_movies.txt","r")
data = file.read()
data
# Out:
# "movie_title     release_dategenre      mpaa_ratingtotal_gross inflation_adjusted_gross\nSnow White\nand the Seven\nDwarfs          1937-12-21 Musical     G           184925485             5228953251\nPinocchio       1940-02-09 Adventure   G            84300000             2188229052\nFantasia        1940-11-13 Musical     G            83320000             2187090808\nSong of the\nSouth           1946-11-12 Adventure   G            65000000             1078510579\nCinderella      1950-02-15 Drama       G            85000000              920608730\n20,000\nLeagues Under\nthe Sea         1954-12-23 Adventure                28200000               528279994\nLady and the\nTramp           1955-06-22 Drama       G            93600000             1236035515\nSleeping\nBeauty          1959-01-29 Drama                     9464608                21505832\n101\nDalmatians      1961-01-25 Comedy      G           153000000             1362870985\nThe Absent\nMinded\nProfessor       1961-03-16 Com
# ...

# %%
movie = data.split('\n')
movie
# Out:
# ['movie_title     release_dategenre      mpaa_ratingtotal_gross inflation_adjusted_gross',
#  'Snow White',
#  'and the Seven',
#  'Dwarfs          1937-12-21 Musical     G           184925485             5228953251',
#  'Pinocchio       1940-02-09 Adventure   G            84300000             2188229052',
#  'Fantasia        1940-11-13 Musical     G            83320000             2187090808',
#  'Song of the',
#  'South           1946-11-12 Adventure   G            65000000             1078510579',
#  'Cinderella      1950-02-15 Drama       G            85000000              920608730',
#  '20,000',
#  'Leagues Under',
#  'the Sea         1954-12-23 Adventure                28200000               528279994',
#  'Lady and the',
#  'Tramp           1955-06-22 Drama       G            93600000             1236035515',
#  'Sleeping',
#  'Beauty          1959-01-29 Drama                     9464608                21505832',
#  '101',
# ...

# %%
movie.pop(0)
# Out:
# 'movie_title     release_dategenre      mpaa_ratingtotal_gross inflation_adjusted_gross'

# %%
movie.pop(0)
# Out:
# 'Snow White'

# %%
movie.pop(0)
# Out:
# 'and the Seven'

# %%
movie.pop()
# Out:
# '\x0c\x0c'

# %%
print(movie)
# Out:
# ['Dwarfs          1937-12-21 Musical     G           184925485             5228953251', 'Pinocchio       1940-02-09 Adventure   G            84300000             2188229052', 'Fantasia        1940-11-13 Musical     G            83320000             2187090808', 'Song of the', 'South           1946-11-12 Adventure   G            65000000             1078510579', 'Cinderella      1950-02-15 Drama       G            85000000              920608730', '20,000', 'Leagues Under', 'the Sea         1954-12-23 Adventure                28200000               528279994', 'Lady and the', 'Tramp           1955-06-22 Drama       G            93600000             1236035515', 'Sleeping', 'Beauty          1959-01-29 Drama                     9464608                21505832', '101', 'Dalmatians      1961-01-25 Comedy      G           153000000             1362870985', 'The Absent', 'Minded', 'Professor       1961-03-16 Comedy                   25381407               310094574', 'Babes in', 'Toyland   
# ...

# %%
# year = input("Enter year :")

for i in movie :
#     print(i)
    s = i.split(' ')
    s
