# %%
file = open("C:\\Users\\BAPS\\Desktop\\test 09-05-2023\\test1111.csv","r")
data = file.read()
data
type(data)
# Out:
# str

# %%
r = data.split("\n")
r
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ['358', 'male', 'group D', 'high school', 'free/reduced', 'completed', 'divorced', 'sometimes', 'no', '1', 'school_bus', '10-May', '68', '60', '60']
# 359,female,group D,some high school,standard,completed,divorced,regularly,yes,6,,,81,95,99
# ['359', 'female', 'group D', 'some high school', 'standard', 'completed', 'divorced', 'regularly', 'yes', '6', '', '', '81', '95', '99']
# 360,male,group B,some college,standard,completed,single,sometimes,yes,2,private,10-May,72,75,72
# ['360', 'male', 'group B', 'some college', 'standard', 'completed', 'single', 'sometimes', 'yes', '2', 'private', '10-May', '72', '75', '72']
# ...

# %%
group = input("enter your group : ").capitalize()
for i in r:
#     print(i)
    sp = i.split(",")
#     print(sp)
    e = sp[2][6:7:]
    if group == e :
        print(i)
# Out:
# enter your group : c
# 1,female,group C,some college,standard,,married,sometimes,yes,0,,10-May,69,90,88
# 4,male,group C,some college,standard,none,married,sometimes,yes,0,school_bus,10-May,76,78,75
# 10,male,group C,associate's degree,standard,none,,sometimes,yes,1,private,10-May,58,54,52
# 15,female,group C,some high school,standard,none,married,sometimes,yes,0,private,,69,75,78
# 16,male,group C,high school,standard,,married,sometimes,yes,0,school_bus,10-May,88,89,86
# 18,male,group C,master's degree,free/reduced,completed,single,sometimes,no,1,private,10-May,46,42,47
# 19,female,group C,associate's degree,free/reduced,none,married,never,yes,3,private,< 5,50,56,58
# 23,female,group C,some high school,standard,none,divorced,never,no,3,,10-May,66,71,71
# 27,female,group C,bachelor's degree,standard,none,married,sometimes,yes,4,school_bus,> 10,69,70,76
# 28,male,group C,high school,standard,none,married,sometimes,no,1,private,10-May,70,70,65
# ...
